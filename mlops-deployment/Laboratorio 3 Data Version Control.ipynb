# %% [markdown]
# # **Laboratorio 3:** Data Version Control
#
# Similar a Git y Github, Data Version Control (DVC) es una herramienta que permite la descentralización del dataset o datasets que fueran a utilizarse en un proyecto, de manera que podamos gestionar diferentes versiones de un dataset en distintas ubicaciones y/o en la nube. Esto permite trabajar en proyectos de ciencia de datos, donde parte del equipo estará recogiendo y etiquetando nuevas muestras, otra parte del equipo estará entrenando los modelos de manera separada y remota. Por otro lado, un equipo de QA podría monitorear los modelos en producción para alertar al equipo sobre cualquier anomalía. Gestionar las diferentes versiones del dataset en este escenario es obligatorio y en este laboratorio veremos un ejemplo de como realizar esta gestión.
#
# <center><img src='https://miro.medium.com/max/700/1*gN7Xru3A-PTavPI6adpJPQ.png' width='40%'></center>
#
# Se sugiriere realizar el presente laboratorio de manera local, ejecutando comandos en la terminal cuando se requiera, debido a que realizar commits hacia Github y guardar datos en Google Drive requiere autenticación, el cual no debería ser compartido en código. El presente laboratorio debe realizarse de manera grupal, por lo que bastara con que uno del equipo lo complete para su proyecto.
#
# El presente notebook fue probado con la versión de Python 3.10.12

# %% [markdown]
# ## 1. Descargar el dataset
#
# Esta vez, usaremos el dataset MNIST desde la librería Scikit-learn, el cual es muy usado por la comunidad para primeros experimentos de Deep Learning y Machine Learning para reconocimiento de imágenes.

# %%
import matplotlib.pyplot as plt
import random

# El modulo datasets de scikitlearn permite descargar un dataset publico con bastante facilidad
# La lista de datasets disponibles se encuentra en https://scikit-learn.org/stable/datasets/toy_dataset.html
from sklearn.datasets import fetch_openml
# La función train_test_split sirve para dividir un dataset pasando como parametro
# a los datos y sus etiquetas
from sklearn.model_selection import train_test_split

# Descargar dataset mnist
X, y = fetch_openml(data_id=554, return_X_y=True, as_frame=False)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=10000
)

# Mostrar la longitud de los subconjuntos y sus anotaciones.
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (60000, 10000, 60000, 10000)

# %%
# Podemos ver que el dataset descargado se encuentra en un array de Numpy y las imágenes
# se encuentran en formato de vectores de 784 elementos. Estos vectores deberan
# ser redimensionados para que las imágenes descargadas sean usables.
print(type(X_train), X_train.shape)
print(type(y_train), y_train.shape)

X_train = X_train.reshape(len(X_train),28,28)
X_test = X_test.reshape(len(X_test),28,28)

print(type(X_train), X_train.shape)
# Out:
# <class 'numpy.ndarray'> (60000, 784)
# <class 'numpy.ndarray'> (60000,)
# <class 'numpy.ndarray'> (60000, 28, 28)

# %%
def plot_samples(num_samples=25, subset_images=None, subset_labels=None):
	'''
		Esta función recibe como atributo a un conjunto de muestras en formato numpy,
		y las muestra en una cuadricula usando matplotlib.
	'''
	# Definir el tamaño de la figura a generarse con Matplotlib
	fig = plt.figure(dpi=100)
	# Mostrar una muestra de n imágenes
	for ix in range(num_samples):
		ax = plt.subplot(5, 5, ix + 1)

		# Seleccionar aleatoriamente un indice del subconjunto de entrenamiento
		i = random.randint(0, len(subset_images)-1)
		# Extraer la imagen y etiqueta
		img, label = subset_images[i], subset_labels[i]
		# Plotear la imagen y agregar la etiqueta como titulo
		ax.imshow(img, cmap='gray')
		ax.set_title(label)
		# Eliminar ejes horizontales y verticales
		ax.axis('off')
	# Ajustar el espacio entre los sub graficos
	plt.tight_layout()
	plt.show()

plot_samples(25, X_test, y_test)

# %% [markdown]
# ## 2. Crear un dataset de ejemplo
#
# Para esta primera versión, usaremos una parte pequeña del dataset MNIST (200 imágenes) y solo mantendremos las etiquetas del digito 7, tomando en cuenta que todos los otros dígitos tienen una mista etiqueta (No dígito 7). Esta versión del dataset podría servirnos para realizar una tarea de clasificación binaria de imágenes. Además, esto también nos servira para ejemplificar la generación de nuevas versiones del dataset.

# %%
import numpy as np

# Filtrar 100 imagenes con la etiqueta '7'
X_train_7 = X_train[y_train == '7'][:100]
y_train_7 = y_train[y_train == '7'][:100]
# Filtrar 100 imagenes sin la etiqueta '7'
X_train_no_7 = X_train[y_train != '7'][:100]
y_train_no_7 = y_train[y_train != '7'][:100]

len(X_train_7), len(X_train_no_7)
# Out:
# (100, 100)

# %%
plot_samples(25, X_train_7, y_train_7)

# %%
plot_samples(25, X_train_no_7, y_train_no_7)

# %% [markdown]
# ## 3. Guardar y ordenar los archivos del dataset
#
# Hasta esta etapa, ya tenemos nuestros subconjuntos filtrados en los arrays de numpy `X_train_7` y `X_train_no_7`. Sin embargo, estas variables (arrays de numpy) tienen las imágenes en la ram y requerimos que estén guardadas en el disco duro. En consecuencia, ahora copiaremos y ordenaremos los archivos hacia una nueva carpeta, la cual contendrá nuestra primera versión del dataset.

# %%
# !ls dataset/train/no7
# Out:
# 00689.png 12156.png 28395.png 42272.png 53899.png 66011.png 76193.png 94410.png
# 01158.png 13313.png 30096.png 42337.png 55119.png 67073.png 77074.png 94844.png
# 01617.png 13839.png 32297.png 45577.png 55145.png 67184.png 81336.png 95383.png
# 02041.png 14555.png 32697.png 45937.png 55646.png 69146.png 81926.png 96125.png
# 05339.png 14623.png 34463.png 47080.png 56809.png 70490.png 82333.png 96454.png
# 06261.png 14770.png 36295.png 47543.png 57190.png 73944.png 83267.png 97728.png
# 07265.png 20846.png 37186.png 47566.png 57573.png 74526.png 86946.png 98044.png
# 07747.png 25309.png 37213.png 48165.png 61540.png 75322.png 87421.png 99129.png
# 10918.png 26372.png 40054.png 48915.png 64164.png 75477.png 89870.png 99256.png
# 12124.png 26569.png 42180.png 49454.png 65031.png 75522.png 89964.png 99383.png

# %%
import os
import shutil

# Path permite representar rutas en formato de objetos
# e integrar rutas con el operador /, para luegar transformar estas a rutas del sistema
# operativo con el que se este trabajando
from pathlib import Path
# Skimage es una librería parte de Scikitlearn para el procesamiento de imágenes,
# en esta ocasión solo lo usaremos para guardar imágenes. Por otro lado imread
# permite leer imágenes.
from skimage.io import imsave, imread
# La librería glob permite generar listado de archivos usando caracteres especiales (* o ?)
# para generalizar los posibles archivos con una sola extensión en una carpeta
from glob import glob

def generate_dataset(path, images_first_category, images_second_category, test_size):
	'''
		Esta función ordena a las imagenes (disponibles en dos arrays Numpy/subconjuntos)
		en subcarpetas tomando en cuenta las categorías. La función
		retorna las rutas de los nuevos archivos en arrays de listas
	'''
	# Si existe la carpeta dataset
	if os.path.exists(path):
		# Eliminar el arbol de directorios completo
		shutil.rmtree(path)
 	# Crear la carpeta 'dataset'
	os.makedirs(path, exist_ok=True)

	# Crear carpetas destino
	splits = ['train', 'test']
	for split in splits:
		os.makedirs(path / split, exist_ok=True)
		os.makedirs(path / split / '7', exist_ok=True)
		os.makedirs(path / split / 'no7', exist_ok=True)

		# Crear los dataframes para train y para test, tomando en cuenta el tamaño
		# del subconjunto de evaluación
		if split == 'train':
			X1, X2 = images_first_category[:-test_size], images_second_category[:-test_size]
		else:
			X1, X2 = images_first_category[-test_size:], images_second_category[-test_size:]

		# Iterar en los subconjuntos de muestras que contienen 3 y los que no,
		# guardando las imágenes respectivas
		for x1, x2 in zip(X1, X2):
			# La función imsave requiere una ruta objetivo para guardar la imagen,
			# y esta imagen debe estar en formato Numpy. También redimensionaremos
			# las imágenes para que tengan 28x28 pixeles.
			imsave(path / split / '7' / f'{random.randint(0, 99999):05d}.png', x1.astype('uint8'))
			imsave(path / split / 'no7' / f'{random.randint(0, 99999):05d}.png', x2.astype('uint8'))

	# Obtener listas con las rutas de las imagenes, para cada subconjunto
	train_7 = glob(str(path / 'train' / '7' / '*.png'))
	train_no7 = glob(str(path / 'train' / 'no7' / '*.png'))
	test_7 = glob(str(path / 'test' / '7' / '*.png'))
	test_no7 = glob(str(path / 'test' / 'no7' / '*.png'))

	return train_7, train_no7, test_7, test_no7

# Crear la carpeta que contendra el proyecto
# !mkdir project
# %cd project

# Definir la ruta del nuevo dataset
new_dataset_path = Path('dataset')

# Ordenar y guardar un dataset de acuerdo a dos arrays de Numpy que contengan
# instancias para dos categorías (X_train_3, X_train_no_3)
train_7, train_no7, test_7, test_no7 = generate_dataset(new_dataset_path, X_train_7, X_train_no_7, 20)

# Mostrar los tamaños de los nuevos subconjuntos generados
len(train_7), len(train_no7), len(test_7), len(test_no7)
# Out:
# /Users/bpdarlyn/Maestria/big-data-articles/mlops-deployment/project
# (80, 80, 20, 20)

# %%
# !pwd
# Out:
# /Users/bpdarlyn/Maestria/big-data-articles/mlops-deployment/project

# %%
print(len(glob("dataset/*/*/*.png")))
# Out:
# 200

# %%
# Mostrar una imagen y su etiqueta desde las rutas guardadas en una lista
def show_sample(paths,label):
	i = random.randint(0, len(paths)-1)
	img = imread(paths[i])
	plt.title(label)
	plt.imshow(img, cmap='gray')
	plt.axis('off')
	plt.tight_layout()
	plt.show()

show_sample(train_7,"7")

# %%
show_sample(train_no7,"No 7")

# %% [markdown]
# ## 4. Versionado del dataset
#
# Hasta esta etapa, ya tenemos organizado nuestro dataset y este se encuentra listo para ser procesado por un modelo de clasificación binaria de digitos (digitos 7 y cualquier otro digito). Sin embargo, el dataset irá evolucionando en el futuro, añadiendo más imágenes y clases. La opción más sencilla para manejar esto sería generar un `.zip` con nuestros datos, ponerle un nombre (por ejemplo, mnist-v1.0) y guardarlo en algún servidor, al cual puedan acceder los miembros de nuestro equipo para entrenar modelos. Sin embargo, no es la mejor estrategía cuando son muchas las versiones que tenemos. En consecuencia, usaremos los conocimientos adquiridos sobre Git y Github para realizar esta tarea de mejor manera. `DVC` trabaja en conjunto con `git`, así que lo primero que necesitaremos será un repositorio de `git` que puedes alojar en `Github`. En mi caso he creado este [repositorio](https://github.com/EdwinTSalcedo/dvc) para este laboratorio.
#
# Posterior a esto, sincronizaremos la carpeta local con una carpeta de GDrive en la nube. La siguiente celda contiene las instrucciones para realizar esta sincronización. Es recomendable ejecutar las siguientes celdas de manera local, con la terminal de su sistema operativo.

# %% [markdown]
# ### 4.1. Inicializar un repositorio en Git y sincronizarlo con Github (Ejecutar en la terminal)

# %%
# Out:
# Initialized empty Git repository in /Users/edwinsalcedo/Desktop/project/.git/
# [main (root-commit) 620233b] First commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 .gitignore
# error: src refspec master does not match any
# error: failed to push some refs to 'github.com:EdwinTSalcedo/DVC.git'

# %% [markdown]
# ### 4.2 Inicializar un repositorio DVC y sincronizarlo con Gdrive (Ejecutar en la terminal)
#
# Deberás ejectuar los siguientes comandos al mismo nivel que el de git, ya que `dvc` utiliza git para el control de version de los metadatos asociados a los datos (archivos grandes). Esto generará una carpeta `.dvc` y un archivo `.dvcignore` similar a git.

# %%
# Instalar dvc
# !pip install dvc 
# !pip install dvc-gdrive 

# Revisar librerías instaladas en PIP y guardarlas en el archivo requirements.txt: pip freeze > requirements.txt
# Instalar librerías desde un archivo requirements.txt: pip install -R requirements.txt

# Inicializar repositorio
# !dvc init

# Añadir la carpeta con los datos al repositorio dvc con el comando
# !dvc add project
# Out:
# Requirement already satisfied: dvc in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (3.62.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (25.3.0)
# Requirement already satisfied: celery in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (5.5.3)
# Requirement already satisfied: colorama>=0.3.9 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (5.0.9)
# Requirement already satisfied: distro>=1.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.2.0)
# Requirement already satisfied: dulwich in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.24.1)
# Requirement already satisfied: dvc-data<3.17,>=3.16.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (3.16.12)
# Requirement already satisfied: dvc-http>=2.29.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.32.0)
# Requirement already satisfied: dvc-objects in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (5.1.1)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.40.2)
# Requirement already satisfied: flatten_dict<1,>=0.4.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.4.2)
# Requirement already satisfied: flufl.lock<9,>=8.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (8.2.0)
# Requirement already satisfied: fsspec>=2024.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2025.7.0)
# Requirement already satisfied: funcy>=1.14 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.8.0)
# Requirement already satisfied: hydra-core>=1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.0.10)
# Requirement already satisfied: kombu in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (5.5.4)
# Requirement already satisfied: networkx>=2.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (3.2.1)
# Requirement already satisfied: omegaconf in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.3.0)
# Requirement already satisfied: packaging>=19 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (25.0)
# Requirement already satisfied: pathspec>=0.10.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (4.3.7)
# Requirement already satisfied: psutil>=5.8 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (5.9.0)
# Requirement already satisfied: pydot>=1.2.4 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (3.2.3)
# Requirement already satisfied: requests>=2.22 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (2.32.5)
# Requirement already satisfied: rich>=12 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (14.1.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.18.15)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (3.5.2)
# Requirement already satisfied: shortuuid>=0.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (1.7.2)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.13.3)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (4.67.1)
# Requirement already satisfied: voluptuous>=0.11.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (0.15.2)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc) (3.0.post1)
# Requirement already satisfied: dictdiffer>=0.8.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc) (3.11.3)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (4.2.1)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (8.1.8)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc) (2.9.0.post0)
# Requirement already satisfied: six<2.0,>=1.12 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from flatten_dict<1,>=0.4.1->dvc) (1.17.0)
# Requirement already satisfied: atpublic in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from flufl.lock<9,>=8.1.0->dvc) (6.0.1)
# Requirement already satisfied: entrypoints in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc) (0.4)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc) (2.11.7)
# Requirement already satisfied: semver>=2.13.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc) (0.16.1)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from kombu->dvc) (5.3.1)
# Requirement already satisfied: tzdata>=2025.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from kombu->dvc) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc) (0.4.1)
# Requirement already satisfied: gitpython>3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc) (3.1.45)
# Requirement already satisfied: pygit2>=1.14.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc) (1.15.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc) (2.21.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc) (2.9.1)
# Requirement already satisfied: cryptography>=39.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (43.0.3)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (3.12.15)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc) (3.0.43)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc) (2.22)
# Requirement already satisfied: urllib3>=1.25 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dulwich->dvc) (2.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc) (5.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from hydra-core>=1.1->dvc) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from omegaconf->dvc) (6.0.2)
# Requirement already satisfied: appdirs in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc) (1.4.4)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc) (3.19.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests>=2.22->dvc) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests>=2.22->dvc) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests>=2.22->dvc) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from rich>=12->dvc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from rich>=12->dvc) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc) (0.1.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc) (0.2.12)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc) (1.5.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc) (78.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc) (1.20.1)
# Requirement already satisfied: dvc-gdrive in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (3.0.1)
# Requirement already satisfied: dvc in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-gdrive) (3.62.0)
# Requirement already satisfied: pydrive2>=1.19.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.21.3)
# Requirement already satisfied: google-api-python-client>=1.12.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.179.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (6.0.2)
# Requirement already satisfied: cryptography<44 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (43.0.3)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=19.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (24.2.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from cryptography<44->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from cffi>=1.12->cryptography<44->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.22)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.40.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (6.32.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.32.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (0.6.1)
# Requirement already satisfied: six>=1.6.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.17.0)
# Requirement already satisfied: fsspec>=2021.07.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2025.7.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive) (4.67.1)
# Requirement already satisfied: funcy>=1.14 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive) (2.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive) (1.4.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (25.3.0)
# Requirement already satisfied: celery in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (5.5.3)
# Requirement already satisfied: colorama>=0.3.9 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (5.0.9)
# Requirement already satisfied: distro>=1.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (2.2.0)
# Requirement already satisfied: dulwich in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.24.1)
# Requirement already satisfied: dvc-data<3.17,>=3.16.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (3.16.12)
# Requirement already satisfied: dvc-http>=2.29.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (2.32.0)
# Requirement already satisfied: dvc-objects in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (5.1.1)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.40.2)
# Requirement already satisfied: flatten_dict<1,>=0.4.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.4.2)
# Requirement already satisfied: flufl.lock<9,>=8.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (8.2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.8.0)
# Requirement already satisfied: hydra-core>=1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.0.10)
# Requirement already satisfied: kombu in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (5.5.4)
# Requirement already satisfied: networkx>=2.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (3.2.1)
# Requirement already satisfied: omegaconf in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (2.3.0)
# Requirement already satisfied: packaging>=19 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (25.0)
# Requirement already satisfied: pathspec>=0.10.3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (4.3.7)
# Requirement already satisfied: psutil>=5.8 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (5.9.0)
# Requirement already satisfied: pydot>=1.2.4 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (2.5.0)
# Requirement already satisfied: rich>=12 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (14.1.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.18.15)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (3.5.2)
# Requirement already satisfied: shortuuid>=0.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (1.7.2)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.13.3)
# Requirement already satisfied: voluptuous>=0.11.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (0.15.2)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc->dvc-gdrive) (3.0.post1)
# Requirement already satisfied: dictdiffer>=0.8.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc->dvc-gdrive) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc->dvc-gdrive) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc->dvc-gdrive) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from dvc-data<3.17,>=3.16.2->dvc->dvc-gdrive) (3.11.3)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (4.2.1)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (8.1.8)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from celery->dvc->dvc-gdrive) (2.9.0.post0)
# Requirement already satisfied: atpublic in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from flufl.lock<9,>=8.1.0->dvc->dvc-gdrive) (6.0.1)
# Requirement already satisfied: entrypoints in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc->dvc-gdrive) (0.4)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc->dvc-gdrive) (2.11.7)
# Requirement already satisfied: semver>=2.13.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc->dvc-gdrive) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc->dvc-gdrive) (0.16.1)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from kombu->dvc->dvc-gdrive) (5.3.1)
# Requirement already satisfied: tzdata>=2025.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from kombu->dvc->dvc-gdrive) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc->dvc-gdrive) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc->dvc-gdrive) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc->dvc-gdrive) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from pydantic!=2.0.0,<3,>=1.9.0->gto<2,>=1.6.0->dvc->dvc-gdrive) (0.4.1)
# Requirement already satisfied: gitpython>3 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (3.1.45)
# Requirement already satisfied: pygit2>=1.14.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (1.15.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (2.21.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (2.9.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (3.12.15)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc->dvc-gdrive) (3.0.43)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (5.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from hydra-core>=1.1->dvc->dvc-gdrive) (4.9.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc->dvc-gdrive) (3.19.1)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc->dvc-gdrive) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from rich>=12->dvc->dvc-gdrive) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from rich>=12->dvc->dvc-gdrive) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc->dvc-gdrive) (0.1.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc->dvc-gdrive) (0.2.12)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc->dvc-gdrive) (1.5.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc->dvc-gdrive) (78.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/mlops3/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc->dvc-gdrive) (1.20.1)
# ERROR: failed to initiate DVC - /Users/bpdarlyn/Maestria/big-data-articles/mlops-deployment/project is not tracked by any supported SCM tool (e.g. Git). Use `--no-scm` if you don't want to use any SCM or `--subdir` if initializing inside a subdirectory of a parent SCM repository.
# ERROR: you are not inside of a DVC repository (checked up to mount point '/')

# %% [markdown]
# > De surgir algún error de conexión con GDrive, se sugiere eliminar archivos temporales que puedan estar siendo leidos por defecto desde la cache de su equipo. Para mas información, seguir los pasos de esta respuesta en [StackOverflow](https://stackoverflow.com/a/76309614).

# %% [markdown]
# Hasta este punto, ya estamos haciendo seguimiento de versiones de nuestro dataset con `dvc`. Esta herramienta permite subir datasets a una variedad de servicios como Google Drive, Firebase, Amazon AWS, entre otros. Puedes utilizar diferentes servicios, [aquí](https://dvc.org/doc/command-reference/remote) tienes un tutorial sobre el comando `remote` que permite agregar repositorios remotos. En este caso utilizaremos [Google Drive](https://drive.google.com/drive/u/0/my-drive) por ser el mas conocido, sin embargo, es bueno mencionar que el Gdrive tiene limites para guardar/transferir archivos, por lo que no es el mejor servicio para DVC. Por otra parte, Gdrive es gratuito a comparación de los otros servicios mencionados.
#
# Para que `dvc` pueda acceder a la carpeta en la que deseamos guardar nuestro dataset en Gdrive, necesitaremos agregar el ID de la carpeta, el cual esta siempre disponible en la url de las carpetas de nuestro Gdrive. Al ejecutar la sincronización, Gdrive pedir permisos de acceso.

# %%
# Agregar un repositorio remoto por defecto en la carpeta con codigo 0AIac4JZqHhKmUk9PDA en Google Drive
# Este codigo (ID) es parte de la url de nuestra carpeta en GDrive
# !dvc remote add --default myremote gdrive://1a5kZbdlIvXl8TAkodyeGHESO6ZhX6ozb

# Evitar errores de seguridad
# !dvc remote modify myremote gdrive_acknowledge_abuse true

# Sincronizar nuestro dataset
# !dvc push

# %% [markdown]
# Ahora puedes probar a eliminar la carpeta `dataset` y para volver a recuperarla puedes ejecutar:

# %%
# !dvc pull dataset.dvc

# %% [markdown]
# Usaremos `git` para crear una nueva versión del dataset. `git` guardará los archivos específicos de `dvc` del commit con el tag determinado.

# %%
# !git add .
# !git commit -m "version 0"
# !git tag -a v0 -m "version 0"
# !git push origin master --tags

# %% [markdown]
# En este punto, cualquiera con acceso al repositorio de `git` y con las credenciales necesarias de `Gdrive` podrá acceder al dataset y a todas sus versiones de manera sencilla y remota para usarlo para entrenar modelos o modificarlo y crear nuevas versiones. Simplemente, usando el siguiente comando:

# %% [markdown]
# ## 5. Crear nueva versión del dataset
#
# Ahora vamos a generar una nueva versión del dataset con 100 muestras más de las que teníamos anteriormente.

# %%
X_train_7 = X_train[y_train == '7'][:200]
X_train_no_7 = X_train[y_train != '7'][:200]

len(X_train_7), len(X_train_no_7)
# Out:
# (200, 200)

# %%
new_dataset_path = Path('dataset')

train_7, train_no7, test_7, test_no7 = generate_dataset(new_dataset_path, X_train_7, X_train_no_7, 40)
len(train_7), len(train_no7), len(test_7), len(test_no7)
# Out:
# (160, 160, 40, 40)

# %%
print(len(glob("dataset/*/*/*.png")))
# Out:
# 400

# %% [markdown]
# Utilizaremos los comando vistos anteriormente para crear una nueva versión.

# %%
# !dvc add dataset
# !dvc push
# !git add .
# !git commit -m 'version 1'
# !git tag -a v1 -m "version 1"
# !git push origin master --tags

# %% [markdown]
# Ahora que tenemos diferentes versiones podemos ir cambiando entre ellas de la siguiente manera.

# %%
# !git checkout tags/v0
# !dvc pull

# %%
# versión 0 con división de 80/20
print("Train - Label 7:",len(os.listdir("dataset/train/7")))
print("Train - Label No 7:",len(os.listdir("dataset/train/no7")))

print("Test - Label 7:",len(os.listdir("dataset/test/7")))
print("Test - Label No 7:",len(os.listdir("dataset/test/no7")))
# Out:
# Train - Label 7: 80
# Train - Label No 7: 80
# Test - Label 7: 20
# Test - Label No 7: 20

# %%
print(len(glob("dataset/*/*/*.png")))
# Out:
# 200

# %% [markdown]
# Retornemos a la versión 1:

# %%
# !git checkout tags/v1
# !dvc pull

# %%
# Versión 1 con división de 160/40

print("Train - Label 7:",len(os.listdir("dataset/train/7")))
print("Train - Label No 7:",len(os.listdir("dataset/train/no7")))

print("Test - Label 7:",len(os.listdir("dataset/test/7")))
print("Test - Label No 7:",len(os.listdir("dataset/test/no7")))
