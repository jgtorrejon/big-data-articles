# %% [markdown]
# # Tare Final Computer Vision
# Detectando Personas (Clasificadas) en una cancha de Fútbol

# %%
from ultralytics import YOLO

# %%
# model = YOLO("models/yolov8x.pt")
model = YOLO("models/best.pt")
results = model.predict("videos/clip_football.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/458) /Users/bpdarlyn/Maestria/big-data-articles/computer_vision/proyecto_yolo/videos/clip_football.mp4: 384x640 17 players, 250.2ms
# video 1/1 (frame 2/458) /Users/bpdarlyn/Maestria/big-data-articles/computer_vision/proyecto_yolo/videos/clip_football.mp4: 384x640 18 players, 238.2ms
# ...
