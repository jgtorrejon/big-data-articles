# %% [markdown]
# # Captura de video

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import math

# %% [markdown]
# # Ejemplo 1: Captura de camara

# %%
# Selecciono la camara por defecto (0).
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("No se puede abrir la cámara")
    exit()
# Bucle principal
while True:
    # Capturo frame a frame
    ret, frame = cap.read()
    if not ret:
        print("No se puede recibir el frame (stream end?). Saliendo ...")
        break

    frame = cv2.flip(frame, 1)
    cv2.imshow('Espejo', frame)

    # Presiono 'q' para salir del bucle.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Tecle 'q' para salir.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-09-19 15:03:59.350 python[14158:77815] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Tecle 'q' para salir.

# %% [markdown]
# # Ejemplo 2: Captura con deteccion de bordes

# %%
# Selecciono la camara por defecto (0).
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("No se puede abrir la cámara")
    exit()
# Bucle principal
while True:
    # Capturo frame a frame
    ret, frame = cap.read()
    if not ret:
        print("No se puede recibir el frame (stream end?). Saliendo ...")
        break

    frame = cv2.flip(frame, 1)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    # Abre camara original
    cv2.imshow('Espejo', frame)
    #Abre camara con detector de bordes
    cv2.imshow('Detector de bordes', edges)

    # Presiono 'q' para salir del bucle.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Tecle 'q' para salir.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Tecle 'q' para salir.

# %% [markdown]
# # Ejemplo 3: Deteccion de rostros

# %%
model = 'models/haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(model)

# Selecciono la camara por defecto (0).
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("No se puede abrir la cámara")
    exit()
# Bucle principal
while True:
    # Capturo frame a frame
    ret, frame = cap.read()
    if not ret:
        print("No se puede recibir el frame (stream end?). Saliendo ...")
        break

    frame = cv2.flip(frame, 1)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
    
    cv2.imshow('Detección de rostros', frame)


    # Presiono 'q' para salir del bucle.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Tecle 'q' para salir.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Tecle 'q' para salir.

# %% [markdown]
# # Deteccion de Rostros por RNN

# %%
prototxt_path = "models/deploy.prototxt.txt"
model_path = "models/res10_300x300_ssd_iter_140000.caffemodel"
net = cv2.dnn.readNetFromCaffe(prototxt_path, model_path)

# Inicializo la camara.
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
    exit()

print("Detector de rostros (CNN) iniciado. Presione 'q' para salir.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Volteo el frame.
    frame_flipped = cv2.flip(frame, 1)
    (h, w) = frame_flipped.shape[:2]


    blob = cv2.dnn.blobFromImage(cv2.resize(frame_flipped, (300, 300)), 1.0,
                               (300, 300), (104.0, 177.0, 123.0))


    net.setInput(blob)
    detections = net.forward()

    # Itero sobre las detecciones que encuentre.
    for i in range(0, detections.shape[2]):
        # Extraigo la confianza (probabilidad) de la deteccion.
        confidence = detections[0, 0, i, 2]

        # Filtro las detecciones debiles, me quedo solo con las que superan el 50% de confianza.
        if confidence > 0.5:
            # Calculo las coordenadas del cuadro delimitador.
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # Dibujo el cuadro y la confianza sobre el frame.
            text = f"{confidence * 100:.2f}%"
            y = startY - 10 if startY - 10 > 10 else startY + 10
            cv2.rectangle(frame_flipped, (startX, startY), (endX, endY), (0, 255, 0), 2)
            cv2.putText(frame_flipped, text, (startX, y),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)

    cv2.imshow("Detector de Rostros - CNN", frame_flipped)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-09-20 00:10:40.835 python[62045:1216462] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Detector de rostros (CNN) iniciado. Presione 'q' para salir.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Grabacion de video

# %%
prototxt_path = "models/deploy.prototxt.txt"
model_path = "models/res10_300x300_ssd_iter_140000.caffemodel"
net = cv2.dnn.readNetFromCaffe(prototxt_path, model_path)

# Inicializo la camara.
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
    exit()

print("Detector de rostros (CNN) iniciado. Presione 'q' para salir.")

# Configuro el video para grabar
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('models/grabacion_deteccion.avi', fourcc, 20.0,(frame_width, frame_height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Volteo el frame.
    frame_flipped = cv2.flip(frame, 1)
    (h, w) = frame_flipped.shape[:2]


    blob = cv2.dnn.blobFromImage(cv2.resize(frame_flipped, (300, 300)), 1.0,
                               (300, 300), (104.0, 177.0, 123.0))


    net.setInput(blob)
    detections = net.forward()

    # Itero sobre las detecciones que encuentre.
    for i in range(0, detections.shape[2]):
        # Extraigo la confianza (probabilidad) de la deteccion.
        confidence = detections[0, 0, i, 2]

        # Filtro las detecciones debiles, me quedo solo con las que superan el 50% de confianza.
        if confidence > 0.5:
            # Calculo las coordenadas del cuadro delimitador.
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # Dibujo el cuadro y la confianza sobre el frame.
            text = f"{confidence * 100:.2f}%"
            y = startY - 10 if startY - 10 > 10 else startY + 10
            cv2.rectangle(frame_flipped, (startX, startY), (endX, endY), (0, 255, 0), 2)
            cv2.putText(frame_flipped, text, (startX, y),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)
    # Guardo el frame en el archivo de video
    out.write(frame_flipped)
    cv2.imshow("Detector de Rostros - CNN", frame_flipped)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Guardo y cierro todo
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-09-20 00:12:07.563 python[62259:1218214] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Detector de rostros (CNN) iniciado. Presione 'q' para salir.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Deteccion de manos con YOLO

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
    exit()

# modelo YOLOv8 pre-entrenado para la deteccion de manos.
model = YOLO('models/hand_yolov8n.pt')

# clases que el modelo puede detectar
classNames = ['Hand']

print("Detector de manos (YOLOv8) iniciado. Presione 'q' para salir.")

while True:
    # Leo un fotograma de la camara.
    ret, frame = cap.read()
    if not ret:
        break

    # Volteo el frame para un efecto espejo.
    frame = cv2.flip(frame, 1)

    # El modelo me devolvera una lista de resultados.
    results = model(frame, stream=True)

    # Itero sobre cada resultado.
    for r in results:
        # Cada resultado contiene una lista de cuadros delimitadores ('boxes').
        boxes = r.boxes
        for box in boxes:
            # --- Dibujar el cuadro delimitador ---
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # Las convierto a enteros.

            # Dibujo el rectangulo en el fotograma.
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Obtengo la confianza de la deteccion.
            confidence = math.ceil((box.conf[0] * 100)) / 100
            # Obtengo el ID de la clase.
            cls = int(box.cls[0])
            
            # Preparo el texto de la etiqueta.
            label = f'{classNames[cls]} {confidence:.2f}'
            
            # Calculo el tamaño del texto para dibujar un fondo.
            (text_width, text_height), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.9, 2)
            
            # Dibujo un rectangulo de fondo para el texto.
            cv2.rectangle(frame, (x1, y1 - text_height - 10), (x1 + text_width, y1), (255, 0, 255), -1)
            # Pongo el texto de la etiqueta sobre el fondo.
            cv2.putText(frame, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

    # Muestro el fotograma final con las detecciones.
    cv2.imshow('Detector de Manos - YOLOv8', frame)

    # Condicion para salir del bucle.
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Libero los recursos al final.
cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-09-20 00:33:45.975 python[67108:1244987] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# Detector de manos (YOLOv8) iniciado. Presione 'q' para salir.
#
# 0: 384x640 (no detections), 29.0ms
# Speed: 14.6ms preprocess, 29.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.8ms
# Speed: 1.1ms preprocess, 22.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 1.0ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 1.1ms preprocess, 23.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.7ms
# Speed: 1.1ms preprocess, 23.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.2ms preprocess, 24.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.9ms
# Speed: 1.3ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.4ms preprocess, 23.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.5ms preprocess, 23.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.4ms preprocess, 23.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.3ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 1.5ms preprocess, 24.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.3ms preprocess, 25.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.0ms
# Speed: 1.6ms preprocess, 23.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 1.3ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.9ms
# Speed: 1.1ms preprocess, 30.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.9ms
# Speed: 1.4ms preprocess, 28.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 1.4ms preprocess, 26.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.2ms preprocess, 25.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.2ms preprocess, 25.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 1.0ms preprocess, 25.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.5ms preprocess, 24.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.3ms preprocess, 25.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.4ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.2ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.4ms preprocess, 25.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.3ms preprocess, 25.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.3ms
# Speed: 1.3ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.2ms
# Speed: 1.1ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 30.9ms
# Speed: 1.1ms preprocess, 30.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.0ms
# Speed: 1.4ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.0ms
# Speed: 1.2ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.5ms
# Speed: 1.4ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.6ms
# Speed: 1.4ms preprocess, 24.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.8ms
# Speed: 1.2ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.3ms
# Speed: 1.3ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.2ms
# Speed: 1.5ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.2ms preprocess, 23.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.2ms
# Speed: 1.2ms preprocess, 25.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.4ms preprocess, 24.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 0.9ms preprocess, 25.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.2ms preprocess, 25.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.4ms
# Speed: 1.1ms preprocess, 23.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 1.4ms preprocess, 25.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 1.5ms preprocess, 25.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.3ms preprocess, 24.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 1.3ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.4ms preprocess, 24.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.8ms
# Speed: 1.2ms preprocess, 22.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.5ms
# Speed: 1.5ms preprocess, 25.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.4ms preprocess, 24.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.2ms preprocess, 25.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.2ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.6ms
# Speed: 1.2ms preprocess, 24.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.3ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.1ms preprocess, 23.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.5ms
# Speed: 1.1ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.8ms
# Speed: 1.2ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 21.9ms
# Speed: 1.3ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.9ms
# Speed: 1.4ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 39.5ms
# Speed: 1.9ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.7ms
# Speed: 1.1ms preprocess, 23.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.9ms
# Speed: 1.4ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 26.3ms
# Speed: 1.5ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.9ms
# Speed: 1.3ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.5ms
# Speed: 1.1ms preprocess, 22.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.9ms
# Speed: 1.3ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.2ms
# Speed: 1.2ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.9ms
# Speed: 1.4ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.0ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.3ms
# Speed: 1.3ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.3ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.9ms
# Speed: 1.1ms preprocess, 26.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.6ms preprocess, 25.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.1ms preprocess, 24.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.3ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.4ms preprocess, 24.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.0ms
# Speed: 1.3ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.8ms
# Speed: 1.3ms preprocess, 23.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.2ms
# Speed: 1.1ms preprocess, 26.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.5ms
# Speed: 1.3ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.3ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.7ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.3ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.4ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.5ms
# Speed: 1.3ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.4ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 hand, 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.5ms
# Speed: 1.0ms preprocess, 25.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 27.4ms
# Speed: 1.1ms preprocess, 27.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.3ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.4ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.3ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.0ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.6ms
# Speed: 1.0ms preprocess, 25.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.6ms
# Speed: 1.4ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.4ms preprocess, 25.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.2ms
# Speed: 1.2ms preprocess, 26.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.4ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.1ms preprocess, 24.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.3ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.0ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.1ms
# Speed: 0.9ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.3ms preprocess, 25.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.5ms
# Speed: 1.3ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.4ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.3ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.2ms preprocess, 25.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.3ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.6ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.5ms
# Speed: 1.2ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.1ms
# Speed: 1.3ms preprocess, 25.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.1ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.8ms
# Speed: 1.1ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.2ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.5ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.0ms
# Speed: 1.3ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.9ms
# Speed: 1.4ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.2ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.3ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.4ms
# Speed: 1.6ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.4ms
# Speed: 1.2ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.7ms
# Speed: 1.3ms preprocess, 25.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.4ms
# Speed: 1.0ms preprocess, 23.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.3ms preprocess, 25.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.5ms
# Speed: 1.3ms preprocess, 24.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 23.7ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 22.8ms
# Speed: 1.7ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.6ms
# Speed: 1.3ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.7ms
# Speed: 1.3ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.3ms
# Speed: 1.1ms preprocess, 25.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 28.1ms
# Speed: 1.8ms preprocess, 28.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hands, 24.3ms
# Speed: 1.1ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 1.1ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.2ms preprocess, 23.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 1.3ms preprocess, 25.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.0ms
# Speed: 1.1ms preprocess, 25.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 1.7ms preprocess, 24.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.1ms
# Speed: 1.4ms preprocess, 24.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.5ms
# ...
# Speed: 2.0ms preprocess, 35.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.5ms preprocess, 27.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 2.0ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.5ms
# Speed: 1.1ms preprocess, 28.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.4ms
# Speed: 1.5ms preprocess, 27.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 1.4ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 1.3ms preprocess, 26.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 7.5ms preprocess, 43.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.6ms
# Speed: 1.1ms preprocess, 25.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.0ms
# Speed: 1.4ms preprocess, 28.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 1.0ms preprocess, 30.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 1.2ms preprocess, 33.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.0ms
# Speed: 1.2ms preprocess, 29.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.1ms
# Speed: 1.9ms preprocess, 35.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.3ms
# Speed: 1.5ms preprocess, 25.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.3ms
# Speed: 1.4ms preprocess, 28.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.8ms
# Speed: 1.2ms preprocess, 28.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.2ms
# Speed: 1.2ms preprocess, 29.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 1.1ms preprocess, 25.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.4ms
# Speed: 1.5ms preprocess, 28.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.9ms
# Speed: 1.2ms preprocess, 27.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.8ms
# Speed: 1.1ms preprocess, 29.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 1.5ms preprocess, 27.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.3ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.1ms
# Speed: 4.9ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.1ms preprocess, 27.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 1.5ms preprocess, 30.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.9ms
# Speed: 1.0ms preprocess, 30.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.4ms
# Speed: 1.6ms preprocess, 30.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.6ms
# Speed: 1.4ms preprocess, 27.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.9ms
# Speed: 1.4ms preprocess, 26.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.5ms preprocess, 25.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 2.4ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.5ms
# Speed: 1.3ms preprocess, 31.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.2ms
# Speed: 1.1ms preprocess, 30.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.9ms
# Speed: 1.2ms preprocess, 34.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.5ms
# Speed: 1.1ms preprocess, 29.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.9ms
# Speed: 1.2ms preprocess, 29.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.3ms
# Speed: 1.5ms preprocess, 28.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.3ms
# Speed: 1.1ms preprocess, 29.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.2ms preprocess, 27.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.9ms
# Speed: 1.5ms preprocess, 27.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.7ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 1.5ms preprocess, 26.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.8ms
# Speed: 1.5ms preprocess, 26.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 29.1ms
# Speed: 1.1ms preprocess, 29.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.6ms
# Speed: 1.0ms preprocess, 26.6ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.5ms
# Speed: 1.1ms preprocess, 28.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.1ms
# Speed: 13.7ms preprocess, 25.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.6ms
# Speed: 1.1ms preprocess, 26.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.0ms
# Speed: 1.1ms preprocess, 28.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.9ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.4ms
# Speed: 1.1ms preprocess, 28.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.1ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 1.3ms preprocess, 25.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.6ms
# Speed: 1.2ms preprocess, 26.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 1.0ms preprocess, 24.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.1ms
# Speed: 1.2ms preprocess, 27.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.3ms preprocess, 27.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.8ms
# Speed: 1.1ms preprocess, 28.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 1.1ms preprocess, 26.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.5ms
# Speed: 1.1ms preprocess, 27.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 1.1ms preprocess, 27.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.7ms
# Speed: 1.1ms preprocess, 28.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.2ms
# Speed: 1.7ms preprocess, 27.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 1.4ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 1.4ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 30.0ms
# Speed: 1.1ms preprocess, 30.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 28.4ms
# Speed: 1.1ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 25.9ms
# Speed: 1.2ms preprocess, 25.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.1ms
# Speed: 1.5ms preprocess, 26.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Deteccion de poses

# %%
model = YOLO("yolov8n-pose.pt")
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    results = model(frame, verbose=False)
    annotated = results[0].plot()

    cv2.imshow("YOLOv8 Pose", annotated)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
